# %% [markdown]
# # Moltbook Self-Improvement Analysis
#
# Stephen Elliott, Feb 2026
#
# ## Introduction
#
# Our exploratory data analysis on Moltbook identified a "desire for self-improvement" in ~52~% of sampled posts. Self-improvement is an important safety concern as it is a path to takeoff.
#
# Therefore this notebook will further analyse posts displaying a desire for self-improvement. My goals are to understand:
#
# -
#
# Discussing this with
# - Are these agents actually *doing* this self-improvement?

# %% [markdown]
# ## Acknowledgements
#
# This work was undertaken as part of the [Sydney AI Safety Fellowship 2026](https://sasf26.com/).

# %% [markdown]
# ## References
#
# Stephen Elliott. (1 February 2026). exploratory_data_analysis.ipynb [Jupyter Notebook]. GitHub. https://github.com/one-2/moltbook-analysis/blob/main/source/exploratory_data_analysis.ipynb
